# %%
fb = open('C:\\Users\\ram\\Desktop\\vocab.enron.txt')
file= fb.read()
print (file)
file_len=len(file)
# Out:
# aaa
# aaas
# aactive
# aadvantage
# aaker
# aap
# aapg
# aaron
# aarp
# aas
# aau
# ab1890
# ab1x
# ab31x
# aba
# abacus
# abag
# abalone
# abandon
# abandoned
# abandoning
# abandonment
# abate
# abated
# abb
# abbott
# abbreviated
# abbreviation
# abby
# abc
# abcm
# abdullah
# abe
# abel
# aberdeen
# abernathy
# aberration
# abeyance
# abhay
# abhyankar
# abide
# abilene
# abilities
# ability
# abitibi
# able
# abn
# abnamro
# abnormal
# aboard
# abolish
# abolished
# abolishing
# abortion
# abound
# aboutface
# aboveaverage
# abovemarket
# abovereferenced
# abraham
# abramson
# abreast
# abroad
# abrogate
# abrogating
# abrupt
# abruptly
# absence
# absences
# absense
# absent
# absentee
# absolute
# absolutely
# absorb
# absorbed
# absorbing
# absorption
# abstain
# abstract
# absurd
# abt
# abu
# abundance
# abundant
# abundantly
# abuse
# abused
# abuses
# abusing
# abusive
# abx
# abx1
# abx2
# aca
# acacia
# academia
# academic
# academically
# academy
# acapulco
# acc
# ...

# %%
print(file_len)
# Out:
# 236180
